# %% [markdown]
# <a href="https://colab.research.google.com/github/MetalCloth/Dog_Cat_Classification/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow
# !pip install kaggle
import pandas as pd
import os
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers,Sequential
from keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, BatchNormalization, Dropout
from tensorflow.keras.callbacks import EarlyStopping

# %%
# !mkdir -p ~/.kaggle
# !mv kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d tongpython/cat-and-dog
# Out:
# Dataset URL: https://www.kaggle.com/datasets/tongpython/cat-and-dog
# License(s): CC0-1.0

# %%
# !unzip cat-and-dog.zip -d /content/dataset

# %%
train_dataset = keras.utils.image_dataset_from_directory(
    directory = '/content/dataset/training_set/training_set',
    labels="inferred",
    label_mode="int",
    class_names=None,
    color_mode="rgb",
    batch_size=32,
    image_size=(256, 256)
)



test_dataset = keras.utils.image_dataset_from_directory(
    directory = '/content/dataset/test_set/test_set',
    labels="inferred",
    label_mode="int",
    class_names=None,
    color_mode="rgb",
    batch_size=32,
    image_size=(256, 256)
)
# Out:
# Found 8005 files belonging to 2 classes.
# Found 2023 files belonging to 2 classes.

# %%
def resize(image,label):
  image = tf.image.resize(image,(256,256))
  return image,label

train_dataset = train_dataset.map(resize)
test_dataset = test_dataset.map(resize)

# %%
model=Sequential()
model.add(Conv2D(32,kernel_size=(3,3),padding='valid',activation='relu',input_shape=(256,256,3)))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2),strides=2,padding='valid'))
model.add(Conv2D(64,kernel_size=(3,3),padding='valid',activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2),strides=2,padding='valid'))
model.add(Conv2D(128,kernel_size=(3,3),padding='valid',activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2),strides=2,padding='valid'))
model.add(Flatten())

model.add(Dense(128,activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(64,activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(32,activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1,activation='sigmoid'))

# %%
early_stopping = EarlyStopping(
    monitor='val_accuracy',
    patience=5,
    restore_best_weights=True
)

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
history=model.fit(train_dataset,epochs=30,validation_data=test_dataset,callbacks=[early_stopping])
# Out:
# Epoch 1/30
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 39s 113ms/step - accuracy: 0.5391 - loss: 3.3486 - val_accuracy: 0.5640 - val_loss: 0.6801
# Epoch 2/30
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 29s 94ms/step - accuracy: 0.5493 - loss: 0.7222 - val_accuracy: 0.5339 - val_loss: 0.7218
# Epoch 3/30
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 39s 85ms/step - accuracy: 0.5440 - loss: 0.7002 - val_accuracy: 0.6391 - val_loss: 0.6469
# Epoch 4/30
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 43s 95ms/step - accuracy: 0.6242 - loss: 0.6619 - val_accuracy: 0.5764 - val_loss: 0.6603
# Epoch 5/30
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 24s 94ms/step - accuracy: 0.6425 - loss: 0.6433 - val_accuracy: 0.6574 - val_loss: 0.6154
# Epoch 6/30
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 22s 87ms/step - accuracy: 0.6987 - loss: 0.5965 - val_accuracy: 0.6426 - val_loss: 0.6175
# Epoch 7/30
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 40s 85ms/step - accuracy: 0.7244 - loss: 0.5465 - val_accuracy: 0.7084 - val_loss: 0.5582
# Epoch 8/30
# ...

# %%
plt.plot(history.history['accuracy'],color='red',label='train')
plt.plot(history.history['val_accuracy'],color='blue',label='validation')
plt.legend()
plt.show()

# %%
import cv2

# %%
test_img=cv2.imread("/content/pexels-photo-2071882.jpg")
plt.imshow(test_img)

# %%
test_img.shape
# Out:
# (753, 500, 3)

# %%
test_img=cv2.resize(test_img,(256,256))
test_input=test_img.reshape((1,256,256,3))

# %%
prediction=model.predict(test_input)
plt.imshow(test_img)
if(prediction[0][0]>0.5):
  plt.xlabel("DOG")

else:
  plt.xlabel("CAT")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step

# %%
img=cv2.imread("/content/download.jpg")
plt.imshow(img)

# %%
img=cv2.resize(img,(256,256))
input=img.reshape((1,256,256,3))

# %%
print("H")
# Out:
# H

# %%
prediction=model.predict(input)
plt.imshow(img)
if(prediction[0][0]>0.5):
  plt.xlabel("DOG")

else:
  plt.xlabel("CAT")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step

# %%
print("H")
# Out:
# H
